# %%
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
train_df = pd.read_csv('data_to_predict.csv', header=None, index_col=False)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14815 entries, 0 to 14814
# Data columns (total 9 columns):
# 0    14815 non-null object
# 1    14815 non-null object
# 2    14815 non-null int64
# 3    14815 non-null int64
# 4    14815 non-null int64
# 5    14815 non-null int64
# 6    14815 non-null int64
# 7    14815 non-null int64
# 8    14815 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
# train_df.csv = shuffle(train_df)

# %%
train_df.columns = [str(x) for x in train_df.columns]

# %%
train_df.head()
# Out:
#         0    1  2  3  4  5  6  7  8
# 0  Aarons  CRY  8  0  2  0  0  1  1
# 1  Aarons  LIV  3  0  0  1  0  0  1
# 2  Aarons  MCI  1  0  0  0  0  0  1
# 3  Aarons  QPR  1  0  0  0  0  0  1
# 4   Abeid  AVL  3  0  0  1  0  0  1

# %%
name_conv = train_df['0'].drop_duplicates()

# %%
name_conv.head()
# Out:
# 0       Aarons
# 4        Abeid
# 15        Adam
# 38    Adebayor
# 60      Adrián
# Name: 0, dtype: object

# %%
int_name = {}
for _ in name_conv:
    int_name[_] = int.from_bytes(_.encode(), 'little')

# %%
int_name = {}
count = 0
for _ in name_conv:
    int_name[_] = count
    count += 1

# %%
#important for conversion
int_name
# Out:
# {'Aarons': 0,
#  'Abeid': 1,
#  'Adam': 2,
#  'Adebayor': 3,
#  'Adrián': 4,
#  'Agbonlahor': 5,
#  'Agger': 6,
#  'Aguero': 7,
#  'Agustien': 8,
#  'Agüero': 9,
#  'Ake': 10,
#  'Akpan': 11,
#  'Akpom': 12,
#  'Aké': 13,
#  'Al-Habsi': 14,
#  'Albrighton': 15,
#  'Alcaraz': 16,
#  'Alderweireld': 17,
#  'Allen': 18,
#  'Alnwick': 19,
#  'Alonso': 20,
#  'Alou Diarra': 21,
#  'Altidore': 22,
#  'Aluko': 23,
#  'Amalfitano': 24,
#  'Amat': 25,
#  'Ameobi': 26,
#  'Amorebieta': 27,
#  'Anderson': 28,
#  'Anelka': 29,
#  'Anichebe': 30,
#  'Anita': 31,
#  'Arfield': 32,
#  'Armero': 33,
#  'Armstrong': 34,
#  'Arnautovic': 35,
#  'Arshavin': 36,
#  'Arteta': 37,
#  'Aspas': 38,
#  'Assaidi': 39,
#  'Assou-Ekotto': 40,
#  'Atsu': 41,
#  'Austin': 42,
#  'Ayoze': 43,
#  'Azpilicueta': 44,
#  'Ba': 45,
#  'Bacuna': 46,
#  'Baines': 47,
#  'Baird': 48,
#  'Baker': 49,
#  'Bale': 50,
#  'Balotelli': 51,
#  'Bannan': 52,
#  'Bardsley': 53,
#  'Barkley': 54,
#  'Barnes': 55,
#  'Barnett': 56,
# ...

# %%
train_df = train_df.replace({'0': int_name})

# %%
# for _ in range(len(train_df)):
#     train_df["0"][_] = int_name[train_df["0"][_]]

# %%
train_df.head()
# Out:
#    0    1  2  3  4  5  6  7  8
# 0  0  CRY  8  0  2  0  0  1  1
# 1  0  LIV  3  0  0  1  0  0  1
# 2  0  MCI  1  0  0  0  0  0  1
# 3  0  QPR  1  0  0  0  0  0  1
# 4  1  AVL  3  0  0  1  0  0  1

# %%
opp_int = train_df['1']
opp = {}
count = 0
for _ in opp_int:
    opp[_] = count
    count +=1

# %%
opp
# Out:
# {'ARS': 14752,
#  'AVL': 14793,
#  'BUR': 14794,
#  'CAR': 14795,
#  'CHE': 14796,
#  'CRY': 14797,
#  'EVE': 14798,
#  'FUL': 14799,
#  'HUL': 14800,
#  'LEI': 14801,
#  'LIV': 14802,
#  'MCI': 14803,
#  'MUN': 14804,
#  'NEW': 14805,
#  'NOR': 14806,
#  'QPR': 14807,
#  'RDG': 14743,
#  'SOU': 14808,
#  'STK': 14809,
#  'SUN': 14810,
#  'SWA': 14811,
#  'TOT': 14812,
#  'WBA': 14813,
#  'WHU': 14814,
#  'WIG': 14751,
#  'uf2': 3917}

# %%
train_df = train_df.replace({'1': opp})

# %%
train_df.head()
# Out:
#    0      1  2  3  4  5  6  7  8
# 0  0  14797  8  0  2  0  0  1  1
# 1  0  14802  3  0  0  1  0  0  1
# 2  0  14803  1  0  0  0  0  0  1
# 3  0  14807  1  0  0  0  0  0  1
# 4  1  14793  3  0  0  1  0  0  1

# %%
# opp_mapping = {}
# for count in range(len(opp)):
#     opp_mapping[opp[count]] = count

# %%
# opp_mapping

# %%
# Index(opp).get_loc('MCI')

# %%
# np.where(opp == 'MCI')

# %%
# import math
# train_df['0'] =  int.from_bytes(train_df['0'].encode(), 'little')

# def convertFromNumber (n):
# return n.to_bytes(math.ceil(n.bit_length() / 8), 'little').decode()

# %%
# int_name.to_bytes(math.ceil(int_name.bit_length() / 8), 'little').decode()
train_df = shuffle(train_df)
train_df.head()
# Out:
#          0      1   2  3  4  5  6  7  8
# 14571  896  14793  14  0  3  1  0  0  4
# 6365   394  14802   4  0  0  0  0  1  3
# 10906  671  14809   3  0  0  0  0  0  4
# 1114    62  14807  12  1  2  1  0  0  2
# 10898  671  14801   0  0  0  0  0  0  1

# %%
X = train_df.drop(['2'],axis=1)
y = train_df['2']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
random_forest = RandomForestRegressor(n_estimators=100)
random_forest.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
Y_pred = random_forest.predict(X_test)
random_forest.score(X_test,y_test)
# Out:
# 0.92237097211692887

# %%
print(random_forest.predict([[21,14797,7,2,0,0,1,1]]))
# Out:
# [ 19.35]
